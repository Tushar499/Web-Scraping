# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Scrape job links from a single page
def scrape_job_links(url, base_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {url}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    job_links = []

    job_cards = soup.find_all('div', class_='sout-jobs-wrapper')
    for job_card in job_cards:
        relative_link = job_card.find('a', href=True)['href'] if job_card.find('a', href=True) else "N/A"
        full_link = f"{base_url}{relative_link}" if relative_link.startswith('jobdetails.asp') else relative_link
        job_links.append(full_link)

    return job_links

# Scrape detailed information from a single job page
def scrape_job_details(job_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'}
    response = requests.get(job_url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {job_url}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    try:
        title = soup.find('h2', class_='jtitle').text.strip() if soup.find('h2', class_='jtitle') else "N/A"
        company = soup.find('h2', class_='cname').text.strip() if soup.find('h2', class_='cname') else "N/A"
        description = soup.find('div', class_='jobcontent').text.strip() if soup.find('div', class_='jobcontent') else "N/A"
        education = soup.find('div', class_='col-sm-12 mb-3').text.strip() if soup.find('div', class_='col-sm-12 mb-3') else "N/A"
        experience = soup.find('div', class_='skills').text.strip() if soup.find('div', class_='skills') else "N/A"
        location = soup.find('div', class_='row mb-3').text.strip() if soup.find('div', class_='row mb-3') else "N/A"
        deadline = soup.find('span', class_='deadlinetxt').text.strip() if soup.find('span', class_='deadlinetxt') else "N/A"
        apply_link = soup.find('a', {'class': 'btn applynow'})['href'] if soup.find('a', {'class': 'btn applynow'}) else "N/A"
    except Exception as e:
        print(f"Error scraping job details from {job_url}: {e}")
        return None

    return {
        'Title': title,
        'Company': company,
        'Description': description,
        'Education': education,
        'Experience': experience,
        'Location' : location,
        'Deadline': deadline,
        'Apply Link': apply_link,
    }

def scrape_all_jobs(base_url, num_pages):
    all_jobs = []

    job_links = []
    for page in range(1, num_pages + 1):
        url = f"{base_url}JobSearch.asp?page={page}"
        print(f"Scraping page {page}: {url}")
        job_links.extend(scrape_job_links(url, base_url))
        time.sleep(random.uniform(2, 5))

    for job_link in job_links:
        print(f"Scraping details for {job_link}")
        job_details = scrape_job_details(job_link)
        if job_details:
            all_jobs.append(job_details)
        time.sleep(random.uniform(2, 5))

    return all_jobs

def save_to_csv(data, filename):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")

if __name__ == "__main__":
    base_url = "https://jobs.bdjobs.com/"
    num_pages = 1

    job_data = scrape_all_jobs(base_url, num_pages)
    save_to_csv(job_data, "bdjobs_details.csv")
# Out:
# Scraping page 1: https://jobs.bdjobs.com/JobSearch.asp?page=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1314010&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1314004&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313999&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313997&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313991&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313979&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313982&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313987&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313985&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313419&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313632&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313966&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313961&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313954&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313962&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313935&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313944&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313960&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313943&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313947&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313950&ln=1
# Data saved to bdjobs_details.csv

# %% [markdown]
# V2

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Scrape job links from a single page
def scrape_job_links(url, base_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {url}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    job_links = []

    job_cards = soup.find_all('div', class_='norm-jobs-wrapper')
    for job_card in job_cards:
        relative_link = job_card.find('a', href=True)['href'] if job_card.find('a', href=True) else "N/A"
        full_link = f"{base_url}{relative_link}" if relative_link.startswith('jobdetails.asp') else relative_link
        job_links.append(full_link)

    return job_links

# Scrape detailed information from a single job page
def scrape_job_details(job_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36'}
    response = requests.get(job_url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {job_url}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    try:
        title = soup.find('h2', class_='jtitle').text.strip() if soup.find('h2', class_='jtitle') else "N/A"
        company = soup.find('h2', class_='cname').text.strip() if soup.find('h2', class_='cname') else "N/A"
        description = soup.find('div', class_='jobcontent').text.strip() if soup.find('div', class_='jobcontent') else "N/A"
        education = soup.find('div', class_='col-sm-12 mb-3').text.strip() if soup.find('div', class_='col-sm-12 mb-3') else "N/A"
        experience = soup.find('div', class_='skills').text.strip() if soup.find('div', class_='skills') else "N/A"
        location = soup.find('div', class_='row mb-3').text.strip() if soup.find('div', class_='row mb-3') else "N/A"
        deadline = soup.find('span', class_='deadlinetxt').text.strip() if soup.find('span', class_='deadlinetxt') else "N/A"
        apply_link = soup.find('a', {'class': 'btn applynow'})['href'] if soup.find('a', {'class': 'btn applynow'}) else "N/A"
    except Exception as e:
        print(f"Error scraping job details from {job_url}: {e}")
        return None

    return {
        'Title': title,
        'Company': company,
        'Description': description,
        'Education': education,
        'Experience': experience,
        'Location': location,
        'Deadline': deadline,
        'Apply Link': apply_link,
    }

# Scrape all jobs across multiple pages
def scrape_all_jobs(base_url, num_pages):
    all_jobs = []

    for page in range(1, num_pages + 1):
        url = f"{base_url}jobsearch.asp?pg={page}&rpp=100&hidJobSearch=JobSearch"
        print(f"Scraping page {page}: {url}")
        job_links = scrape_job_links(url, base_url)
        time.sleep(random.uniform(2, 5))

        for job_link in job_links:
            print(f"Scraping details for {job_link}")
            job_details = scrape_job_details(job_link)
            if job_details:
                all_jobs.append(job_details)
            time.sleep(random.uniform(2, 5))

    return all_jobs

def save_to_csv(data, filename):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")

if __name__ == "__main__":
    base_url = "https://jobs.bdjobs.com/"
    num_pages = 5

    job_data = scrape_all_jobs(base_url, num_pages)
    save_to_csv(job_data, "bdjobs_details.csv")
# Out:
# Scraping page 1: https://jobs.bdjobs.com/jobsearch.asp?pg=1&rpp=100&hidJobSearch=JobSearch
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1314016&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313978&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313974&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1314006&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313861&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1314003&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313996&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313383&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313989&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313980&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313986&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313972&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313928&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313975&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313970&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313915&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313733&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313969&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313964&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313967&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313905&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313764&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313958&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313956&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313959&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313919&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313952&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313932&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313957&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313955&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313892&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313951&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313939&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313886&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313936&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313176&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313887&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313875&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313810&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313940&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313539&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313882&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313931&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313910&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313916&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313792&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313922&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313795&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313906&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313908&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313847&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312937&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313738&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313901&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313883&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313899&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313898&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313056&ln=1
# Scraping page 2: https://jobs.bdjobs.com/jobsearch.asp?pg=2&rpp=100&hidJobSearch=JobSearch
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313468&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313458&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313791&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313789&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313786&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313784&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313897&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313895&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313854&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313608&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313469&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313868&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313884&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313891&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313827&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313704&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312757&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313853&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313858&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313371&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313645&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313865&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313864&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313859&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313850&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313856&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313793&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313849&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313846&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313852&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313790&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313836&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313820&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313753&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313840&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313837&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313828&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313819&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313796&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313769&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313800&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313815&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313801&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313802&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313508&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313664&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313798&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313783&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313797&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313452&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313741&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1311200&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313518&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313781&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313757&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313773&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313750&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313737&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313770&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313763&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312864&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313767&ln=1
# Scraping page 3: https://jobs.bdjobs.com/jobsearch.asp?pg=3&rpp=100&hidJobSearch=JobSearch
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313751&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313209&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312903&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313732&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313746&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1310358&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1310341&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312443&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313018&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1310363&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1310583&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313742&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313072&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1311134&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313745&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313726&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313706&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313687&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313739&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313712&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313731&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313728&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313729&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313727&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313720&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313725&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313716&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313721&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313087&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313713&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313684&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313714&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313613&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313696&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312741&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313243&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313709&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313710&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313707&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313537&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313695&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313668&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313686&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313685&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313689&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313644&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313683&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313677&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313674&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313663&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1311547&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1311487&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313662&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312912&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313652&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313353&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313648&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313651&ln=1
# Scraping page 4: https://jobs.bdjobs.com/jobsearch.asp?pg=4&rpp=100&hidJobSearch=JobSearch
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313573&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1309402&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313640&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313636&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313637&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313635&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313626&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313623&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313618&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313622&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313619&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313614&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313615&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313610&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313607&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313606&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313567&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1309311&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313503&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313552&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313232&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313528&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313483&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313445&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313382&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312355&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313380&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313368&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313592&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313480&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313077&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313591&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313292&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313585&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313507&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313365&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313558&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313385&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313378&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313367&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313010&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313008&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313005&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313001&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312979&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313578&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313582&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313527&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313494&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313479&ln=1
# Scraping page 5: https://jobs.bdjobs.com/jobsearch.asp?pg=5&rpp=100&hidJobSearch=JobSearch
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313576&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313535&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313401&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1311196&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313570&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313553&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313568&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313418&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313443&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313148&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313571&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313348&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313562&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313554&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313563&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313516&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313560&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313549&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313544&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313541&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313517&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313540&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313546&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313460&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313464&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313530&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313525&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313477&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313523&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313485&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313470&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313515&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313482&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313498&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313505&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313274&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313495&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313481&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313491&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313489&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313420&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313474&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313473&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1312917&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313425&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313417&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313352&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313002&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313453&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313455&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313471&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313296&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313447&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313463&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313326&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313461&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1311956&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313454&ln=1
# Scraping details for https://jobs.bdjobs.com/jobdetails.asp?id=1313370&ln=1
# Data saved to bdjobs_details.csv
